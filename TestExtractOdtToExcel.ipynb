# %%
from odf.opendocument import load
from odf.text import P
from odf.opendocument import OpenDocumentSpreadsheet
from odf.table import Table, TableRow, TableCell
from odf.text import P as TableP
import pandas as pd

class MINERAL:
    def __init__(self, name, color=None, formula=None, formulaWeight=None, otherSpecies=None, discovery=None, system=None, 
                 magnetism=None, crystal_class=None, radioactivity=None, mohs=None, density=None, fusion_temperature=None,
                 macle=None, fluorescence=None, cleavage=None, habitus=None, glow=None, pleochroism=None, chemicalBehaviour=None,
                 transparence=None, gite=None, associatedMinerals=None, gisement=None, use=None, synonyme=None, topotype=None, infoSup=None):
        self.name = name
        self.color = color
        self.formula = formula
        self.formulaWeight = formulaWeight
        self.otherSpecies = otherSpecies
        self.discovery = discovery
        self.system = system
        self.magnetism = magnetism
        self.crystal_class = crystal_class
        self.radioactivity = radioactivity
        self.mohs = mohs
        self.density = density
        self.fusion_temperature = fusion_temperature
        self.macle = macle
        self.fluorescence = fluorescence
        self.cleavage = cleavage
        self.habitus = habitus
        self.glow = glow
        self.pleochroism = pleochroism
        self.chemicalBehaviour = chemicalBehaviour
        self.transparence =  transparence
        self.gite = gite
        self.associatedMinerals = associatedMinerals
        self.gisement = gisement
        self.use = use
        self.synonyme = synonyme
        self.topotype = topotype
        self.infoSup = infoSup

    def to_dict(self):
        return {
            'Name': self.name,
            'Color': self.color,
            'Formula': self.formula,
            'FormulaWeight': self.formulaWeight,
            'OtherSpecies': self.otherSpecies,
            'Discovery': self.discovery,
            'System': self.system,
            'Magnetism': self.magnetism,
            'Crystal Class': self.crystal_class,
            'Radioactivity': self.radioactivity,
            'Mohs': self.mohs,
            'Density': self.density,
            'Fusion_Temperature': self.fusion_temperature,
            'Macle': self.macle,
            'Fluorescence': self.fluorescence,
            'Cleavage': self.cleavage,
            'Habitus': self.habitus,
            'Glow': self.glow,
            'Pleochroism': self.pleochroism,
            'ChemicalBehaviour': self.chemicalBehaviour,
            'Transparence': self.transparence,
            'Gite': self.gite,
            'associatedMinerals': self.associatedMinerals,
            'Gisement': self.gisement,
            'Use': self.use,
            'Synonyme': self.synonyme,
            'Topotype': self.topotype,
            'InfoSup': self.infoSup
        }

def get_paragraph_text(paragraph):
    texts = []
    for node in paragraph.childNodes:
        if node.nodeType == node.TEXT_NODE:
            texts.append(node.data)
        elif node.nodeType == node.ELEMENT_NODE and node.tagName == 'text:span':
            texts.append(node.firstChild.data)
    return ''.join(texts).strip()

# Charger le document ODT
doc = load('MineralTestExtract.odt')

# Initialiser des listes pour les minéraux et leurs propriétés
minerals = []

# Parcourir les paragraphes du document pour extraire les informations
current_mineral = None
Mineral_data = []
Index, i=[], -1

print(doc.getElementsByType(P)[1])

for paragraph in doc.getElementsByType(P):
    i+=1
    text = get_paragraph_text(paragraph)
    #print(text)
    #print('\n')
    key_value = text.split(" ")
    #print(key_value)
    if len(key_value)==1:
        if key_value[0].find(":")==-1 and key_value[0]!="":
            minerals.append(key_value[0])
            Index.append(i)
Index.append(len(doc.getElementsByType(P)))      

for i in range(len(Index)-1): 
    mineral_data = MINERAL
    for i in range(Index[i]+1,Index[i+1]-1):
        text = get_paragraph_text(doc.getElementsByType(P)[i])
        key_value = text.split(": ")
        #print(key_value)
        if key_value[0].find("Couleur")!=-1:
            mineral_data.color=key_value[1:][0]
        elif key_value[0].find("Formule")!=-1:
            mineral_data[1]=key_value[1:][0]
        elif key_value[0].find("Masse formulaire")!=-1:
            mineral_data[2]=key_value[1:][0]
        elif key_value[0].find("Autres espèces possiblement présentes")!=-1:
            mineral_data[3]=key_value[1:][0]
        elif key_value[0].find("Découverte")!=-1:
            mineral_data[4]=key_value[1:][0]
        elif key_value[0].find("Système cristallin")!=-1:
            mineral_data[5]=key_value[1:][0]
        elif key_value[0].find("Magnétisme")!=-1:
            mineral_data[6]=key_value[1:][0]
        elif key_value[0].find("Classe cristalline")!=-1:
            mineral_data[7]=key_value[1:][0]
        elif key_value[0].find("Radioactivité")!=-1:
            mineral_data[8]=key_value[1:][0]
        elif key_value[0].find("Echelle de Mohs")!=-1:
            mineral_data[9]=key_value[1:][0]
        elif key_value[0].find("Densité")!=-1:
            mineral_data[10]=key_value[1:][0]
        elif key_value[0].find("Température de fusion")!=-1:
            mineral_data[11]=key_value[1:][0]
        elif key_value[0].find("Macle")!=-1:
            mineral_data[12]=key_value[1:][0]
        elif key_value[0].find("Fluorescence")!=-1:
            mineral_data[13]=key_value[1:][0]
        elif key_value[0].find("Clivage")!=-1:
            mineral_data[14]=key_value[1:][0]
        elif key_value[0].find("Habitus")!=-1:
            mineral_data[15]=key_value[1:][0]
        elif key_value[0].find("Eclats")!=-1:
            mineral_data[16]=key_value[1:][0]
        elif key_value[0].find("Pléochroisme")!=-1:
            mineral_data[17]=key_value[1:][0]
        elif key_value[0].find("Comportement chimique")!=-1:
            mineral_data[18]=key_value[1:][0]
        elif key_value[0].find("Transparence")!=-1:
            mineral_data[19]=key_value[1:][0]
        elif key_value[0].find("Gîte")!=-1:
            mineral_data[20]=key_value[1:][0]
        elif key_value[0].find("associée aux minéraux")!=-1:
            mineral_data[21]=key_value[1:][0]
        elif key_value[0].find("Gisement")!=-1:
            mineral_data[22]=key_value[1:][0]
        elif key_value[0].find("Utilisation")!=-1:
            mineral_data[23]=key_value[1:][0]
        elif key_value[0].find("Synonyme")!=-1:
            mineral_data[24]=key_value[1:][0]
        elif key_value[0].find("Topotype")!=-1:
            mineral_data[25]=key_value[1:][0]
        elif key_value[0].find("InfoSup")!=-1:
            mineral_data[26]=key_value[1:][0]
   
    Mineral_data.append(mineral_data)
        
print(minerals)
print('Mineral_data')
print(Mineral_data)
# Out:
# du latin rutilus, rouge, en référence à sa couleur rouge
# ['Rutile', 'Cassitérite', 'Anatase']
# Mineral_data
# [['noir, rouge sombre, jaune vif', 'TiO2', '79,866\xa0±\xa00,002\xa0uma - O\xa040,07\xa0%, Ti\xa059,93\xa0%', None, 'Décrit par Abraham Gottlob Werner en 1803', 'tétragonal', 'aucun', 'ditétragonale dipyramidale\xa0; 4/mmm', 'aucune', '6-6.5', '4,2-4,3', '-', 'Macle sur {101} (en genou), sur {321} (en cœur)', 'aucune -', 'bon sur {110}, peu net sur{100}', 'octaèdrique', None, None, None, 'transparent, translucide ou opaque', '- Minéral accessoire courant dans de nombreuses roches métamorphiques (gneiss, micaschistes, granulites, éclogites, etc.) - Dans les roches magmatiques (granites, syénites,\xa0etc.) et des pegmatites et filons de quartz - Dans des sables alluvionnaires - Présent dans les roches lunaires - Présent dans des météorites', 'adulaire, albite, anatase, apatite, brookite, calcite, chlorite, hématite, ilménite, pyrophyllite, quartz, titanite.', '- Canada, Kimmirut (Lake Harbour), île de Baffin, Territoire du Nunavut - France, Carrière de Trimouns, Luzenac, Ariège, Midi-Pyrénées', 'Minerai de titane, pierre gemme pour la taille', 'cajuélite, crispite, dicksbergite, édisonite, gallitzinite, naumannite, paraedrite, rutilite, titane oxydé, titanite', 'Espagne, Cajuelo, Vuitrago, Burgos, Castille et Leon', None], ['Brun', 'SnO2', '150,709\xa0±\xa00,008\xa0uma - O\xa021,23\xa0%, Sn\xa078,77\xa0%', 'Fe, Ta, Nb, Zn, W, Mn, Sc, Ge, In et Ga', 'Cité par Bergmann en 1780, première analyse chimique faite par Martin Heinrich Klaproth en 1797, décrite par François sulpice Bendant en 1832', 'tétragonale', 'aucun', 'ditétragonale-dipyramidale', 'aucune', '6-7', '6.3 - 7.2', '1630 °C', 'macle en genou', 'aucune', 'clivage imparfait-indistinct', 'cristaux prismatiques ou en masses, macles fréquentes', None, None, 'réagit à l’HCl', 'transparent à opaque', 'se trouve dans les roches magmatiques acides et dans des gîtes alluvionnaires associée aux minéraux\xa0', None, '- France\xa0', "L’étain est obtenu par réduction en chauffant cassitérite et carbone à au moins 1200 °C. Gîte principale de l’étain\xa0pour l'extraction de l’étain pour faire du Bronze (alliage de cuivre-étain)", None, None, None], ['brun, bleu, noir, incolore, grisâtre, verdâtre, vert bleuâtre, jaune, rouge', 'TiO2', '79,866\xa0±\xa00,002\xa0uma - O\xa040,07\xa0%, Ti\xa059,93\xa0%', None, 'Découvert à la fin du XVIIIepar Jean-Godefroy Schreiber', 'tétragonale', 'aucun', 'Ditétragonale-dipyramidale, I 41/amd', 'aucune', '5.5-6', '3,9-4', '1843 °C', 'Macle sur {112}', 'aucune', 'parfaits sur {001} et {101}', 'Pseudo-octaédrique, bipyramidal pointu, tabulaire, prismatique, columnaire. Cristaux striés.', None, None, None, 'transparent, translucide', "Dans les fentes alpines des gneiss et micaschistes - se trouve également dans des filons de pegmatites et sous forme de grains roulés dans certaines roches sédimentaires. Les cristaux peuvent atteindre jusqu'à 3,75\xa0cm", 'adulaire, axinite, brookite, épidote, préhnite, quartz, ilménite, hématite', "- Allemagne, Grube Louise Charlotte, Hasserode, Wernigerode, Harz, Sachsen-Anhalt - Belgique, Daverdisse, Wellin, Province de Luxembourg - Canada, Carrière Sintra, Ayer's Cliff, région de l'Estrie, Québec - France, Plessis en Laz, Châteauneuf-du-Faou, Finistère Carrière de la Lande, Plumelin, Morbihan - Italie, Miniera di Buca della Vena, Ponte Stazzemese, Stazzema, Alpes Apuane, Lucca, Toscane - Norvège, Dyrfonni (Dyrefonni), Viveli, Eidfjord, Hardangervidda, Hordaland", 'pierre gemme – pigment blanc', 'dauphinite, hydrotitanite, octaédrite, oisanite, Schorl bleu indigo, Schorl octaédre rectangulaire, wisérine, Xanthitane ou xanthotitane', "Saint-Christophe-en-Oisans, Bourg-d'Oisans, Isère, France", None]]

# %%
from odf.opendocument import load
from odf.text import P
from odf.opendocument import OpenDocumentSpreadsheet
from odf.table import Table, TableRow, TableCell
from odf.text import P as TableP
import pandas as pd

class MINERAL:
    def __init__(self, name, color=None):
        self.name = name
        self.color = color

    def to_dict(self):
        return {
            'Name': self.name,
            'Color': self.color,

        }

def get_paragraph_text(paragraph):
    texts = []
    for node in paragraph.childNodes:
        if node.nodeType == node.TEXT_NODE:
            texts.append(node.data)
        elif node.nodeType == node.ELEMENT_NODE and node.tagName == 'text:span':
            texts.append(node.firstChild.data)
    return ''.join(texts).strip()

# Charger le document ODT
doc = load('MineralTestExtract.odt')

# Initialiser des listes pour les minéraux et leurs propriétés
minerals = []

# Parcourir les paragraphes du document pour extraire les informations
current_mineral = None
Mineral_data = []
Index, i=[], -1

print(doc.getElementsByType(P)[1])

for paragraph in doc.getElementsByType(P):
    i+=1
    text = get_paragraph_text(paragraph)
    #print(text)
    #print('\n')
    key_value = text.split(" ")
    #print(key_value)
    if len(key_value)==1:
        if key_value[0].find(":")==-1 and key_value[0]!="":
            minerals.append(key_value[0])
            Index.append(i)
Index.append(len(doc.getElementsByType(P)))      

for i in range(len(Index)-1): 
    mineral_data = MINERAL(i)
    for i in range(Index[i]+1,Index[i+1]-1):
        text = get_paragraph_text(doc.getElementsByType(P)[i])
        key_value = text.split(": ")
        #print(key_value)
        if key_value[0].find("Couleur")!=-1:
            mineral_data.color=key_value[1:][0]
    Mineral_data.append(mineral_data)
    print(mineral_data.color)
        
print(minerals)
print('Mineral_data')
print(Mineral_data)
print(Mineral_data[0].color)
print(Mineral_data[1].color)
print(Mineral_data[2].color)
# Out:
# du latin rutilus, rouge, en référence à sa couleur rouge
# noir, rouge sombre, jaune vif
# Brun
# brun, bleu, noir, incolore, grisâtre, verdâtre, vert bleuâtre, jaune, rouge
# ['Rutile', 'Cassitérite', 'Anatase']
# Mineral_data
# [<__main__.MINERAL object at 0x0000023047988AD0>, <__main__.MINERAL object at 0x00000230479350D0>, <__main__.MINERAL object at 0x00000230476E75D0>]
# noir, rouge sombre, jaune vif
# Brun
# brun, bleu, noir, incolore, grisâtre, verdâtre, vert bleuâtre, jaune, rouge
